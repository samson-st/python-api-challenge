# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install geoviews
# !pip install cartopy.crs

# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
import cartopy.crs as ccrs
import geoviews as gv

# Import API key
from api_keys import geoapify_key
# Out:
# Requirement already satisfied: geoviews in c:\users\samso\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: shapely in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (3.2.2)
# Requirement already satisfied: xyzservices in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (2023.7.0)
# Requirement already satisfied: pyproj in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (3.4.0)
# Requirement already satisfied: packaging in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (0.21.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (1.17.0)
# Requirement already satisfied: param in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (1.12.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (1.2.1)
# Requirement already satisfied: numpy in c:\users\samso\anaconda3\lib\site-packages (from geoviews) (1.21.5)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (2.0.0)
# Requirement already satisfied: contourpy>=1 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.1.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (2.11.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\samso\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.2.0)
# Requirement already satisfied: pyshp>=2.1 in c:\users\samso\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\samso\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.5.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\samso\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.0.2)
# Requirement already satisfied: colorcet in c:\users\samso\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.0)
# Requirement already satisfied: bleach in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.3.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.4.0)
# Requirement already satisfied: linkify-it-py in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.2)
# Requirement already satisfied: requests in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.28.1)
# Requirement already satisfied: markdown in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.3.4)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.64.1)
# Requirement already satisfied: markdown-it-py in c:\users\samso\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: certifi in c:\users\samso\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\samso\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\samso\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samso\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\samso\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\samso\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samso\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samso\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\samso\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\samso\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.5)
# Requirement already satisfied: webencodings in c:\users\samso\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\samso\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\samso\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.4.8)
# Requirement already satisfied: uc-micro-py in c:\users\samso\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\samso\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\samso\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samso\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\samso\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.15)
# ERROR: Could not find a version that satisfies the requirement cartopy.crs (from versions: none)
# ERROR: No matching distribution found for cartopy.crs
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25172\3428628262.py in <module>
#       8 import json
#       9 import cartopy.crs as ccrs
# ---> 10 import geoviews as gv
#      11
#      12 # Import API key
#
# ~\anaconda3\lib\site-packages\geoviews\__init__.py in <module>
#       7 from holoviews import render, save # noqa (API import)
#       8
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#      11     _Element, Feature, Tiles, WMTS, LineContours, FilledContours,
#
# ~\anaconda3\lib\site-packages\geoviews\annotators.py in <module>
#      13 from .models.custom_tools import CheckpointTool, RestoreTool, ClearTool
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#      17
#
# ~\anaconda3\lib\site-packages\geoviews\operation\__init__.py in <module>
#       5 from .. import element as gv_element
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#       9     project_graph, project_quadmesh, project_geom, project)
#
# ~\anaconda3\lib\site-packages\geoviews\operation\projection.py in <module>
#      13 from shapely.geometry.collection import GeometryCollection
#      14
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#      17                        RGB, Graph, Nodes, EdgePaths, QuadMesh, VectorField,
#
# ~\anaconda3\lib\site-packages\geoviews\data\__init__.py in <module>
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface # noqa (API import)
#
# ~\anaconda3\lib\site-packages\geoviews\data\geopandas.py in <module>
#       8
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#      12 from holoviews.core.data import PandasInterface
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (C:\Users\samso\anaconda3\lib\site-packages\holoviews\core\data\__init__.py)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv('../output_data/cities.csv')

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness
# 0        0         faya  18.3851   42.4509     22.06        35          21  \
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
plot_1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True, 
    tiles = 'OSM', 
    frame_width = 700, 
    frame_height = 500, 
    color='City',
    alpha= 0.5,
    s='Humidity',
    scale= 0.8)

# Display the map
plot_1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import cartopy.crs as ccrs
# --> 233         import geoviews as gv # noqa
#     234         import pyproj
#
# ~\anaconda3\lib\site-packages\geoviews\__init__.py in <module>
#       8
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#
# ~\anaconda3\lib\site-packages\geoviews\annotators.py in <module>
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#
# ~\anaconda3\lib\site-packages\geoviews\operation\__init__.py in <module>
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#
# ~\anaconda3\lib\site-packages\geoviews\operation\projection.py in <module>
#      14
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#
# ~\anaconda3\lib\site-packages\geoviews\data\__init__.py in <module>
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface # noqa (API import)
#
# ~\anaconda3\lib\site-packages\geoviews\data\geopandas.py in <module>
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (C:\Users\samso\anaconda3\lib\site-packages\holoviews\core\data\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25172\3005327951.py in <module>
#       1 # Configure the map plot
# ----> 2 plot_1 = city_data_df.hvplot.points(
#       3     'Lng',
#       4     'Lat',
#       5     geo=True,
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#     520             The HoloViews representation of the plot.
#     521         """
# --> 522         return self(x, y, kind='points', **kwds)
#     523
#     524     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#      80                 return pn.panel(plot, **panel_dict)
#      81
# ---> 82         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      83
#      84     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#      87         y = y or params.pop('y', None)
#      88         kind = kind or params.pop('kind', None)
# ---> 89         return HoloViewsConverter(
#      90             self._data, x, y, kind=kind, **params
#      91         )
#
# ~\anaconda3\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     386         self.dynamic = dynamic
#     387         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 388         self.crs = self._process_crs(data, crs) if self.geo else None
#     389         self.project = project
#     390         self.coastline = coastline
#
# ~\anaconda3\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     628         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     629         try:
# --> 630             return process_crs(_crs)
#     631         except ValueError:
#     632             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     234         import pyproj
#     235     except ImportError:
# --> 236         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     237
#     238     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df.loc[(city_data_df['Max Temp']<=12)\
                            &(city_data_df['Max Temp']>=0)\
                            &(city_data_df['Cloudiness']<=90)\
                            &(city_data_df['Country']!='US')\
                            &(city_data_df['Country']!='AU')\
                            &(city_data_df['Country']!='IN')\
                            &(city_data_df['Country']!='RU')\
                            &(city_data_df['Country']!='CN')\
                            &(city_data_df['Humidity']<70),:]
print(len(ideal_df))


# Drop any rows with null values
ideal_df.dropna()

# Display sample data
ideal_df.head()
# Out:
# 9
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness
# 171      171    la ronge  55.1001 -105.2842      5.14        52          75  \
# 222      222   hay river  60.8156 -115.7999     10.99        58          40
# 250      250       floro  61.5996    5.0328      9.04        61          40
# 262      262    thompson  55.7435  -97.8558      1.09        60          40
# 331      331  swan river  52.1058 -101.2676      0.94        40           0
#
#      Wind Speed Country        Date
# 171        2.57      CA  1666108339
# 222        3.60      CA  1666108369
# 250        6.69      NO  1666108384
# 262        3.60      CA  1666108392
# 331        2.06      CA  1666108431

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df.iloc[:,[1,8,2,3,5]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']=''

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 171    la ronge      CA  55.1001 -105.2842        52
# 222   hay river      CA  60.8156 -115.7999        58
# 250       floro      NO  61.5996    5.0328        61
# 262    thompson      CA  55.7435  -97.8558        60
# 331  swan river      CA  52.1058 -101.2676        40

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {'categories':'accommodation.hotel',\
         'filter':'',\
         'bias':'',\
         'apiKey':geoapify_key,\
         'limit':1}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# la ronge - nearest hotel: No hotel found
# hay river - nearest hotel: No hotel found
# floro - nearest hotel: No hotel found
# thompson - nearest hotel: No hotel found
# swan river - nearest hotel: No hotel found
# aktau - nearest hotel: No hotel found
# mandalgovi - nearest hotel: No hotel found
# bulgan - nearest hotel: No hotel found
# sorland - nearest hotel: No hotel found
#            City Country      Lat       Lng  Humidity      Hotel Name
# 171    la ronge      CA  55.1001 -105.2842        52  No hotel found
# 222   hay river      CA  60.8156 -115.7999        58  No hotel found
# 250       floro      NO  61.5996    5.0328        61  No hotel found
# 262    thompson      CA  55.7435  -97.8558        60  No hotel found
# 331  swan river      CA  52.1058 -101.2676        40  No hotel found
# 428       aktau      KZ  43.6500   51.2000        46  No hotel found
# 532  mandalgovi      MN  45.7625  106.2708        23  No hotel found
# 555      bulgan      MN  48.8125  103.5347        40  No hotel found
# 556     sorland      NO  67.6670   12.6934        67  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
plot_4 = hotel_df.hvplot.points('Lng',
            'Lat',
            geo=True, 
            tiles = 'OSM', 
            frame_width = 700, 
            frame_height = 500, 
            color='City',
            alpha=0.6,
            hover=True,
            hover_cols='all',
            use_index=False,
            s='Humidity',
            scale= 1.2)

# Display the map
plot_4
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import cartopy.crs as ccrs
# --> 233         import geoviews as gv # noqa
#     234         import pyproj
#
# ~\anaconda3\lib\site-packages\geoviews\__init__.py in <module>
#       8
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#
# ~\anaconda3\lib\site-packages\geoviews\annotators.py in <module>
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#
# ~\anaconda3\lib\site-packages\geoviews\operation\__init__.py in <module>
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#
# ~\anaconda3\lib\site-packages\geoviews\operation\projection.py in <module>
#      14
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#
# ~\anaconda3\lib\site-packages\geoviews\data\__init__.py in <module>
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface # noqa (API import)
#
# ~\anaconda3\lib\site-packages\geoviews\data\geopandas.py in <module>
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (C:\Users\samso\anaconda3\lib\site-packages\holoviews\core\data\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25172\2934493375.py in <module>
#       1 # Configure the map plot
# ----> 2 plot_4 = hotel_df.hvplot.points('Lng',
#       3             'Lat',
#       4             geo=True,
#       5             tiles = 'OSM',
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#     520             The HoloViews representation of the plot.
#     521         """
# --> 522         return self(x, y, kind='points', **kwds)
#     523
#     524     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#      80                 return pn.panel(plot, **panel_dict)
#      81
# ---> 82         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      83
#      84     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#      87         y = y or params.pop('y', None)
#      88         kind = kind or params.pop('kind', None)
# ---> 89         return HoloViewsConverter(
#      90             self._data, x, y, kind=kind, **params
#      91         )
#
# ~\anaconda3\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     386         self.dynamic = dynamic
#     387         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 388         self.crs = self._process_crs(data, crs) if self.geo else None
#     389         self.project = project
#     390         self.coastline = coastline
#
# ~\anaconda3\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     628         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     629         try:
# --> 630             return process_crs(_crs)
#     631         except ValueError:
#     632             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     234         import pyproj
#     235     except ImportError:
# --> 236         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     237
#     238     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.
